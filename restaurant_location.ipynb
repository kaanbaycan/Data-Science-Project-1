# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/Users/berk/Desktop/IstDataAcademy/Github/Data-Science-Project-1/Open_Restaurant_Applications.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13765 entries, 0 to 13764
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   objectid                                  13765 non-null  int64
#  1   globalid                                  13765 non-null  object
#  2   Seating Interest (Sidewalk/Roadway/Both)  13765 non-null  object
#  3   Restaurant Name                           13764 non-null  object
#  4   Legal Business Name                       13764 non-null  object
#  5   Doing Business As (DBA)                   13753 non-null  object
#  6   Building Number                           12776 non-null  object
#  7   Street                                    13765 non-null  object
#  8   Borough                                   13765 non-null  object
#  9   Postcode                                  13765 non-null  int64
# ...

# %%
df.head()
# Out:
#    objectid                                globalid  \
# 0     13610  {FD87ABAA-860E-4762-845D-8F0403D0246B}
# 1      5900  {3B07E4C0-07B7-4079-8333-64446CC3EE03}
# 2     13018  {137C575D-DC14-4F9D-83D9-A3FFE513B3B8}
# 3     11630  {15270732-2A78-4C24-89DD-BE8DD916F115}
# 4     13137  {EF9C8173-91D1-496E-8BD4-B02BEADC2A21}
#
#   Seating Interest (Sidewalk/Roadway/Both)            Restaurant Name  \
# 0                                  roadway               MADAME BONTE
# 1                                 sidewalk             Seasoned Vegan
# 2                                 sidewalk  AMERICAS CAFE &amp; GRILL
# 3                                  roadway                 SUSHI SEKI
# 4                                  roadway            Sami &amp; Susu
#
#    Legal Business Name    Doing Business As (DBA) Building Number  \
# 0        BEANHOUSE LLC               MADAME BONTE             NaN
# 1  Seasoned Vegan, LLC        Seasoned Vegan, LLC              55
# ...

# %%
df['Seating Interest (Sidewalk/Roadway/Both)'].value_counts()
# Out:
# both           6928
# sidewalk       4648
# roadway        1825
# openstreets     364
# Name: Seating Interest (Sidewalk/Roadway/Both), dtype: int64
